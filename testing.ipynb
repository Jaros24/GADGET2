# %%
import GADGET2
import numpy as np
import sys
import os
import importlib
import matplotlib.pyplot as plt
import time

# reload GADGET2 to pick up changes
importlib.reload(GADGET2)
# %matplotlib widget

# %%
# SAMPLE WORKFLOW
plt.close('all')
path = GADGET2.generate_files(273, length=90, ic=600000, pads=5, eps=5, samps=5, poly=2, overwrite=False)
runh5 = GADGET2.GadgetRunH5(273, folder_path=path)
GADGET2.plot_spectrum(GADGET2.to_MeV(runh5.total_energy), units="MeV", num_bins=1000)
example_good_event = runh5.good_events[1000]
GADGET2.range_vs_energy.show_event(runh5, example_good_event)
runh5.h5_file.plot_3d_traces(example_good_event, threshold=500)
# Out:
# Files Already Exist.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
