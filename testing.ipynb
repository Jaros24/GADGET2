# %%
import GADGET2
import numpy as np
import sys
import os
import importlib
import matplotlib.pyplot as plt

# reload GADGET2 to pick up changes
importlib.reload(GADGET2)
# Out:
# <module 'GADGET2' from '/mnt/analysis/e17023/Adam/GADGET2/src/GADGET2/__init__.py'>

# %%
GADGET2.GenerateFiles.generate_files(139, ic=9999999999, length=999, overwrite=False)
# Out:
# 100%|██████████| 2245/2245 [00:04<00:00, 449.85it/s]
# Starting # of Events: 2245
# Events Below Threshold: 142
# Vetoed Events: 885
# Events Missing Cloud: 477
# Final # of Good Events: 741
# DIRECTORY: /mnt/analysis/e21072/h5test/run_0139/len999_ic9999999999_pads21_eps7_samps8_poly2/

# %%
runh5 = GADGET2.RunH5.GadgetRunH5(139, folder_path="/home/adam/GADGET2/data/run_0139/len999_ic9999999999_pads21_eps7_samps8_poly2/")

# %%
plt.imshow(GADGET2.ImagesCNN.make_grid())
