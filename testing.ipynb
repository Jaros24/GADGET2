# %%
import GADGET2
import numpy as np
import sys
import os
import importlib
import matplotlib.pyplot as plt
import time

# reload GADGET2 to pick up changes
importlib.reload(GADGET2)
# %matplotlib widget

# %%
# SAMPLE WORKFLOW
plt.close('all')
GADGET2.generate_files(139, length=9999, ic=9999999999, overwrite=True)
runh5 = GADGET2.GadgetRunH5(139)
GADGET2.plot_spectrum(runh5.total_energy)

first_good_event_num = runh5.good_events[0]
runh5.h5_file.plot_3d_traces(first_good_event_num, threshold=500)
# Out:
# 100%|██████████| 2245/2245 [00:01<00:00, 1142.84it/s]
# Starting # of Events: 2245
# Events Below Threshold: 142
# Vetoed Events: 885
# Events Missing Cloud: 477
# Final # of Good Events: 741
# DIRECTORY: /home/adam/GADGET2/data/run_0139/len9999_ic9999999999_pads21_eps7_samps8_poly2/
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
